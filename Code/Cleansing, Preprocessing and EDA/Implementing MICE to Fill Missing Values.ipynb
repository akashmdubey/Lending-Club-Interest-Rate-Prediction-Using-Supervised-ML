# %% [markdown]
# # Import the Dataset

# %%
import pandas as pd

# %%
dataset = pd.read_csv("../Data/Mice Data/data_for_mice.csv",header=0,encoding='utf-8')
df = dataset.copy()
df.head()
# Out:
#    Unnamed: 0  loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# 0           0       5000         5000           4975.0     3     10.65
# 1           1       2500         2500           2500.0     5     15.27
# 2           2       2400         2400           2400.0     3     15.96
# 3           3      10000        10000          10000.0     3     13.49
# 4           4       3000         3000           3000.0     5     12.69
#
#    installment  emp_length  annual_inc  issue_month           ...            \
# 0       162.87        10.0     24000.0           12           ...
# 1        59.83         0.0     30000.0           12           ...
# 2        84.33        10.0     12252.0           12           ...
# 3       339.31        10.0     49200.0           12           ...
# 4        67.79         1.0     80000.0           12           ...
#
#    loan_status_Does not meet the credit policy. Status:Charged Off  \
# 0                                                  0
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0       5000         5000           4975.0     3     10.65       162.87
# 1       2500         2500           2500.0     5     15.27        59.83
# 2       2400         2400           2400.0     3     15.96        84.33
# 3      10000        10000          10000.0     3     13.49       339.31
# 4       3000         3000           3000.0     5     12.69        67.79
#
#    emp_length  annual_inc  issue_month  issue_year           ...            \
# 0        10.0     24000.0           12        2011           ...
# 1         0.0     30000.0           12        2011           ...
# 2        10.0     12252.0           12        2011           ...
# 3        10.0     49200.0           12        2011           ...
# 4         1.0     80000.0           12        2011           ...
#
#   loan_status_Does not meet the credit policy. Status:Charged Off  \
# 0                                                  0
# ...

# %%
imp = mice.MICEData(df)
imp.set_imputer('x1', formula='x2 + np.square(x2) + x3')
for j in range(20):
    imp.update_all()
imp.data.to_csv("../Data/Mice Data/data_after_mice.csv")
