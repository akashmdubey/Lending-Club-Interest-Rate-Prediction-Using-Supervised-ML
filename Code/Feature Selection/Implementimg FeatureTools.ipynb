# %% [markdown]
# # We have used Feature Tools for Feature Importance

# %%
#import necessary package
import pandas as pd
import featuretools as ft

# %% [markdown]
# # Reading the file

# %%
df = pd.read_csv("../Data/Original Data/feature.csv",header=0,encoding='utf-8')

# %%
df
# Out:
#           issue_d grade sub_grade        term addr_state
# 0       11-Dec-19     B        B2   36 months         AZ
# 1       11-Dec-19     C        C4   60 months         GA
# 2       11-Dec-19     C        C5   36 months         IL
# 3       11-Dec-19     C        C1   36 months         CA
# 4       11-Dec-19     B        B5   60 months         OR
# 5       11-Dec-19     A        A4   36 months         AZ
# 6       11-Dec-19     C        C5   60 months         NC
# 7       11-Dec-19     E        E1   36 months         CA
# 8       11-Dec-19     F        F2   60 months         CA
# 9       11-Dec-19     B        B5   60 months         TX
# 10      11-Dec-19     C        C3   60 months         AZ
# 11      11-Dec-19     B        B5   36 months         CA
# 12      11-Dec-19     C        C1   36 months         VA
# 13      11-Dec-19     B        B1   36 months         IL
# 14      11-Dec-19     B        B2   36 months         CA
# 15      11-Dec-19     D        D1   36 months         MO
# 16      11-Dec-19     C        C4   36 months         CA
# 17      11-Dec-19     A        A1   36 months         CT
# 18      11-Dec-19     B        B3   36 months         UT
# 19      11-Dec-19     A        A1   36 months         CA
# 20      11-Dec-19     C        C4   60 months         TX
# 21      11-Dec-19     B        B4   36 months         FL
# 22      11-Dec-19     B        B3   36 months         TX
# 23      11-Dec-19     B        B3   36 months         CA
# 24      11-Dec-19     B        B3   36 months         CA
# 25      11-Dec-19     B        B1   36 months         IL
# 26      11-Dec-19     C        C2   36 months         NY
# 27      11-Dec-19     D        D2   60 months         PA
# 28      11-Dec-19     B        B3   36 months         FL
# 29      11-Dec-19     B        B3   36 months         MN
# ...           ...   ...       ...         ...        ...
# 887349  15-Jan-19     A        A3   36 months         FL
# 887350  15-Jan-19     C        C3   60 months         CA
# 887351  15-Jan-19     D        D2   36 months         CO
# 887352  15-Jan-19     B        B5   36 months         MD
# 887353  15-Jan-19     B        B4   60 months         FL
# 887354  15-Jan-19     D        D5   36 months         GA
# 887355  15-Jan-19     A        A5   36 months         UT
# 887356  15-Jan-19     D        D1   60 months         MT
# 887357  15-Jan-19     D        D5   60 months         KY
# 887358  15-Jan-19     D        D2   60 months         NC
# 887359  15-Jan-19     D        D1   60 months         MN
# 887360  15-Jan-19     B        B1   60 months         NY
# 887361  15-Jan-19     A        A1   36 months         MA
# 887362  15-Jan-19     A        A5   36 months         NM
# 887363  15-Jan-19     B        B2   36 months         NV
# 887364  15-Jan-19     A        A1   36 months         FL
# 887365  15-Jan-19     C        C4   36 months         IN
# 887366  15-Jan-19     D        D3   36 months         FL
# 887367  15-Jan-19     A        A2   36 months         FL
# 887368  15-Jan-19     C        C5   60 months         NC
# 887369  15-Jan-19     B        B1   36 months         CA
# 887370  15-Jan-19     B        B2   36 months         WI
# 887371  15-Jan-19     E        E2   36 months         OH
# 887372  15-Jan-19     B        B5   36 months         OH
# 887373  15-Jan-19     D        D1   36 months         TX
# 887374  15-Jan-19     B        B5   36 months         CA
# 887375  15-Jan-19     B        B5   36 months         NJ
# 887376  15-Jan-19     D        D2   60 months         TN
# 887377  15-Jan-19     E        E3   60 months         MA
# 887378  15-Jan-19     B        B5   36 months         FL
#
# [887379 rows x 5 columns]

# %%
# Make an entityset and add the entity
es = ft.EntitySet(id = 'data')
es.entity_from_dataframe(entity_id = 'data', dataframe = df, 
                         make_index = True, index = 'index')
# Out:
# Entityset: data
#   Entities:
#     data [Rows: 887379, Columns: 6]
#   Relationships:
#     No relationships

# %% [markdown]
# # List all the avaliable primitives

# %%
ft.list_primitives()
# Out:
#                             name         type  \
# 0                  n_most_common  aggregation
# 1               time_since_first  aggregation
# 2                           last  aggregation
# 3                           skew  aggregation
# 4                          trend  aggregation
# 5                   percent_true  aggregation
# 6               avg_time_between  aggregation
# 7                            max  aggregation
# 8                            any  aggregation
# 9                            sum  aggregation
# 10                           std  aggregation
# 11                      num_true  aggregation
# 12                           min  aggregation
# 13                        median  aggregation
# 14                         count  aggregation
# 15               time_since_last  aggregation
# 16                    num_unique  aggregation
# 17                          mode  aggregation
# 18                           all  aggregation
# 19                          mean  aggregation
# 20                       is_null    transform
# 21           time_since_previous    transform
# 22                           day    transform
# 23           greater_than_scalar    transform
# 24                num_characters    transform
# 25                          isin    transform
# 26                      absolute    transform
# 27                  equal_scalar    transform
# 28                            or    transform
# 29             modulo_by_feature    transform
# ..                           ...          ...
# 46                          diff    transform
# 47                           and    transform
# 48         greater_than_equal_to    transform
# 49            less_than_equal_to    transform
# 50                        minute    transform
# 51                      latitude    transform
# 52                      cum_mean    transform
# 53                        second    transform
# 54              not_equal_scalar    transform
# 55  greater_than_equal_to_scalar    transform
# 56                divide_numeric    transform
# 57       multiply_numeric_scalar    transform
# 58                     less_than    transform
# 59                     num_words    transform
# 60                modulo_numeric    transform
# 61              subtract_numeric    transform
# 62                       cum_max    transform
# 63                       cum_sum    transform
# 64                    percentile    transform
# 65              less_than_scalar    transform
# 66                     haversine    transform
# 67             divide_by_feature    transform
# 68                          year    transform
# 69                     not_equal    transform
# 70                         equal    transform
# 71                           not    transform
# 72                    days_since    transform
# 73                          week    transform
# 74                   add_numeric    transform
# 75                  greater_than    transform
#
#                                           description
# 0   Finds the N most common elements in a categori...
# 1                  Time since first related instance.
# 2                             Returns the last value.
# 3                Computes the skewness of a data set.
# 4   Calculates the slope of the linear trend of va...
# 5   Finds the percent of 'True' values in a boolea...
# 6   Computes the average time between consecutive ...
# 7   Finds the maximum non-null value of a numeric ...
# 8                        Test if any value is 'True'.
# 9      Sums elements of a numeric or boolean feature.
# 10  Finds the standard deviation of a numeric feat...
# 11    Finds the number of 'True' values in a boolean.
# 12  Finds the minimum non-null value of a numeric ...
# 13  Finds the median value of any feature with wel...
# 14              Counts the number of non null values.
# 15                  Time since last related instance.
# 16  Returns the number of unique categorical varia...
# 17  Finds the most common element in a categorical...
# 18                     Test if all values are 'True'.
# 19   Computes the average value of a numeric feature.
# 20  For each value of base feature, return 'True' ...
# 21      Compute the time since the previous instance.
# 22         Transform a Datetime feature into the day.
# 23
# 24  Return the number of characters in a given str...
# 25  For each value of the base feature, checks whe...
# 26                    Absolute value of base feature.
# 27
# 28
# 29
# ..                                                ...
# 46  Compute the difference between the value of a ...
# 47
# 48
# 49
# 50     Transform a Datetime feature into the "minute.
# 51  Returns the first value of the tuple base feat...
# 52         Returns the cumulative mean after grouping
# 53      Transform a Datetime feature into the second.
# 54
# 55
# 56
# 57
# 58
# 59  Returns the number of words in a given string ...
# 60
# 61
# 62          Returns the cumulative max after grouping
# 63          Returns the cumulative sum after grouping
# 64  For each value of the base feature, determines...
# 65
# 66  Calculate the approximate haversine distance i...
# 67
# 68        Transform a Datetime feature into the year.
# 69
# 70
# 71  For each value of the base feature, negates th...
# 72  For each value of the base feature, compute th...
# 73        Transform a Datetime feature into the week.
# 74
# 75
#
# [76 rows x 3 columns]

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'data',
                                      trans_primitives = ['year', 'month'])

feature_matrix.head()
# Out:
#       grade sub_grade        term addr_state  YEAR(issue_d)  MONTH(issue_d)
# index
# 0         B        B2   36 months         AZ           2019              12
# 1         C        C4   60 months         GA           2019              12
# 2         C        C5   36 months         IL           2019              12
# 3         C        C1   36 months         CA           2019              12
# 4         B        B5   60 months         OR           2019              12

# %%
feature_matrix.to_csv('../Data/Original Data/feature_gained.csv')

# %% [markdown]
# ------- Feature Tools vs Manual Feature -----
# Feature tool helps a user to find some features that are necessary for mathematical calculation like avg,min,max,count etc.
# Feature tool have a lots of limitation like you need to pass proper entities before gaining features out of it.
# so, if a user needs to find some function related to maths then feature tool is useful. Feature tool works well only with the numeric data.
# A user needs to decide manually first what features he need and the pass the primitives accordingly.In short it is manually feature selection .
